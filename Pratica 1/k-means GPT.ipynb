# %% [markdown]
# <h4>
# Código gerado por chat GPT
# </h4>

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Carrega os dados do arquivo CSV
def load_data(filename):
    return pd.read_csv(filename)

# %%
# Função para aplicar o algoritmo K-means
def apply_kmeans(data, n_clusters):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(data)
    return kmeans

# %%
# Função para plotar os clusters
def plot_clusters(data, kmeans):
    plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=kmeans.labels_, cmap='viridis')
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', color='red', label='Centroids')
    plt.title('K-means Clustering')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend()
    plt.show()

# %%
# Nome do arquivo CSV
filename = 'iris.csv'

# Número de clusters desejado
n_clusters = 3

# Carrega os dados
data = load_data(filename)
data = data.drop('ESPECIE', axis=1)

# Aplica o algoritmo K-means
kmeans_model = apply_kmeans(data, n_clusters)

# Plota os clusters
plot_clusters(data, kmeans_model)
# Out:
# c:\Users\marci\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
